# %% [markdown]
# <a href="https://colab.research.google.com/github/Goga270/HomeWork2_ML/blob/main/Hometasks/Base/AI_HW2_GD_base_Aladinskiy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Домашнее задание 2: Градиентный спуск (base)**
#
# В этом задании две части - теоретическая и практическая. Теорию можно набирать, используя LaTex или просто решать на листочке, сфотографировать и отправить вместе с заполненным ноутбуком в anytask.
#
# Максимальный балл за домашнее задание: min{10, ваш балл}.

# %% [markdown]
# ## Задание 1 (0.5 балла)

# %% [markdown]
# Найдите экстремумы следующих функций (вручную, где возможно) и укажите их тип (максимум, минимум):
#
# a) $f(x) = x^2 - 30x + 1$
#
# b) $g(x) = -x^3 + 5x - 7x^2 + 17$
#
# c) $h(x) = x^2 - 1/x$
#
# d) $j(x) = 1/x^5 + x^{17} + 8$

# %% [markdown]
# В ПДФ

# %% [markdown]
# ## Задание 2 (1 балл)

# %% [markdown]
# Найдите экстремумы этих функций в Python.

# %%
# your code here
import sympy as sp
def extr_func(func, critical_points):
    for point in critical_points:
        try:
            second_derivative = f_double_prime.subs(x, point)
            function_value = func.subs(x, point).evalf()
            if second_derivative > 0:
                extremum_type = 'минимум'
            elif second_derivative < 0:
                extremum_type = 'максимум'
            else:
                extremum_type = 'седло'
            print(f'Функция f(x): экстремум при x = {point}, это {extremum_type}, значение функции f({point}) = {function_value}')
        except:
            pass

# %%
x = sp.Symbol('x')

a = x**2 - 30*x + 1
b = -x**3 + 5*x - 7*x**2 + 17
c = x**2 - 1/x
d = 1/x**5 + x**17 + 8

a_prime = sp.diff(a, x)
critical_points_a = sp.solve(a_prime, x)
f_double_prime = sp.diff(a_prime, x)

extr_func(a, critical_points_a)

print('**********************')

b_prime = sp.diff(b, x)
critical_points_b = sp.solve(b_prime, x)
f_double_prime = sp.diff(b_prime, x)

extr_func(b, critical_points_b)

print('**********************')

c_prime = sp.diff(c, x)
critical_points_c = sp.solve(c_prime, x)
c_double_prime = sp.diff(c_prime, x)

extr_func(c, critical_points_c)

print('**********************')

d_prime = sp.diff(d, x)
critical_points_d = sp.solve(d_prime, x)
f_double_prime = sp.diff(d_prime, x)

extr_func(d, critical_points_d)
# Out:
# Функция f(x): экстремум при x = 15, это минимум, значение функции f(15) = -224.000000000000
# **********************
# Функция f(x): экстремум при x = -5, это минимум, значение функции f(-5) = -58.0000000000000
# Функция f(x): экстремум при x = 1/3, это максимум, значение функции f(1/3) = 17.8518518518519
# **********************
# Функция f(x): экстремум при x = -2**(2/3)/2, это максимум, значение функции f(-2**(2/3)/2) = 1.88988157484231
# **********************
# Функция f(x): экстремум при x = -17**(21/22)*5**(1/22)/17, это максимум, значение функции f(-17**(21/22)*5**(1/22)/17) = 6.29091200972848
# Функция f(x): экстремум при x = 17**(21/22)*5**(1/22)/17, это минимум, значение функции f(17**(21/22)*5**(1/22)/17) = 9.70908799027152

# %% [markdown]
# ## Задание 3 (1 балл)

# %% [markdown]
# Найдите точки перегиба функций из задания 1 (вручную, где возможно).

# %% [markdown]
# В ПДФ

# %% [markdown]
# ## Задание 4 (1 балла)

# %% [markdown]
# Найдите точки перегиба этих функций в Python.

# %%
import sympy as sp

x = sp.Symbol('x')

functions = {
    'x**2 - 30*x + 1': x**2 - 30*x + 1,
    '-x**3 + 5*x - 7*x**2 + 17': -x**3 + 5*x - 7*x**2 + 17,
    'x**2 - 1/x': x**2 - 1/x,
    '1/x**5 + x**17 + 8': 1/x**5 + x**17 + 8,
}

for func_name, func in functions.items():
    print(f'\nТочки перегиба для {func_name}: {func}')

    first_derivative = sp.diff(func, x)

    second_derivative = sp.diff(first_derivative, x)
    print(f'  Вторая производная: {second_derivative}')

    inflection_points = sp.solve(sp.Eq(second_derivative, 0), x)
    print(f'  Критические точки (f''(x) = 0): {inflection_points}')

    third_derivative = sp.diff(second_derivative, x)
    for point in inflection_points:
        try:
            point_eval = point.evalf(chop=True)
            if point_eval.is_real:
                third_derivative_value = third_derivative.subs(x, point_eval).evalf()
                print(f"    x = {point_eval}: f'''(x) = {third_derivative_value}")
                if third_derivative_value != 0:
                    print('    Это точка перегиба')
                else:
                    print("    Точка не является точкой перегиба (f'''(x) = 0)")
            else:
                print(f'    Комплексное решение x = {point} пропускаем')
        except:
            pass
# Out:
# Точки перегиба для x**2 - 30*x + 1: x**2 - 30*x + 1
#   Вторая производная: 2
#   Критические точки (f(x) = 0): {inflection_points}
#
# Точки перегиба для -x**3 + 5*x - 7*x**2 + 17: -x**3 - 7*x**2 + 5*x + 17
#   Вторая производная: -6*x - 14
#   Критические точки (f(x) = 0): {inflection_points}
#     x = -2.33333333333333: f'''(x) = -6.00000000000000
#     Это точка перегиба
#
# Точки перегиба для x**2 - 1/x: x**2 - 1/x
#   Вторая производная: 2 - 2/x**3
#   Критические точки (f(x) = 0): {inflection_points}
#     x = 1.00000000000000: f'''(x) = 6.00000000000000
#     Это точка перегиба
#     Комплексное решение x = -1/2 - sqrt(3)*I/2 пропускаем
#     Комплексное решение x = -1/2 + sqrt(3)*I/2 пропускаем
#
# Точки перегиба для 1/x**5 + x**17 + 8: x**17 + 8 + x**(-5)
#   Вторая производная: 272*x**15 + 30/x**7
#   Критические точки (f(x) = 0): {inflection_points}
# ...

# %% [markdown]
# ### Внимание! Далее все задания необходимо выполнять для ВСЕХ функций из задания 1!
#
# ## Задание 5 (1 балл)

# %% [markdown]
# Постройте графики функций из задания 1 в Python (не забудьте подписать оси и сами графики):
# *   изобразите графики с подписанными осями
# *   отметьте одним цветом локальные экстремумы
# *   отметьте другим цветом точки перегиба
# *   подпишите на оси x значения экстремумов и точек перегиба
#
# P.S. Для того, чтобы отметить точку на графике, вам понадобится функция (plt.scatter), а для того, чтобы подписать её значение на оси (plt.annotate).

# %% [markdown]
# Пример хорошего графика:
#
# ![good_graph.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, diff, solve


def plot_extr_points(func, label, lambda_func, min_x, max_x):
    try:
        f_prime = diff(func, x)
        f_double_prime = diff(f_prime, x)

        extrema_x = solve(f_prime, x)
        extrema_y = [func.subs(x, val) for val in extrema_x]

        inflection_x = solve(f_double_prime, x)
        inflection_y = [func.subs(x, val) for val in inflection_x]

        f = lambda_func

        x_vals = np.linspace(min_x, max_x, max_x - min_x)
        y_vals = f(x_vals)

        plt.figure(figsize=(10, 6))

        plt.plot(x_vals, y_vals, label=label, color='blue')

        for x_extr, y_extr in zip(extrema_x, extrema_y):
            plt.scatter(float(x_extr), float(y_extr), color='red', label='Экстремум')
            plt.annotate(f'({x_extr:.2f}, {y_extr:.2f})', (float(x_extr), float(y_extr) + 5),
                        textcoords='offset points', xytext=(-20, 5), ha='center', color='red')

        for x_infl, y_infl in zip(inflection_x, inflection_y):
            plt.scatter(float(x_infl), float(y_infl), color='green', label='Точка перегиба')
            plt.annotate(f'({x_infl:.2f}, {y_infl:.2f})', (float(x_infl), float(y_infl) - 10),
                        textcoords='offset points', xytext=(-20, -15), ha='center', color='green')

        plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
        plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
        plt.xlabel('x', fontsize=12)
        plt.ylabel('f(x)', fontsize=12)
        plt.title('График функции с экстремумами и точками перегиба', fontsize=14)
        plt.legend(loc='upper right')
        plt.grid(True)

        plt.show()
    except:
        pass
plot_extr_points(a, 'x**2 - 30*x + 1', lambda x: x**2 - 30*x + 1, 0, 20)

# %%
plot_extr_points(b, '-x**3 + 5*x - 7*x**2 + 17', lambda x: -x**3 + 5*x - 7*x**2 + 17, -10, 10)

# %%
plot_extr_points(c, 'x**2 - 1/x', lambda x: x**2 - 1/x, -20, 20)

# %%
plot_extr_points(d, '1/x**5 + x**17 + 8', lambda x: 1/x**5 + x**17 + 8, -5, 5)

# %% [markdown]
# ## Задание 6 (1 балл)

# %% [markdown]
# Модифицируйте функцию, осуществляющую метод градиентного спуска с семинара: добавьте опцию останавливать метод, если абсолютное значение производной функции в точке < некоторого $\delta$ (delta добавьте в аргументы функции).

# %%
def gradient_descent(x_start, learning_rate, epsilon, delta, num_iterations, lambda_func):
    x = sp.symbols('x')
    f = lambda_func
    df_x = sp.diff(f(x))

    x_curr = x_start
    trace = [x_curr]

    for i in range(num_iterations):
        grad = df_x.subs(x, x_curr)
        if abs(grad) < delta:
            print(f"Остановка: |f'(x)| = {abs(grad):.4f} < delta = {delta}")
            return x_curr, trace

        x_new = x_curr - learning_rate * grad
        trace.append(x_new)

        if abs(x_new - x_curr) < epsilon:
            print(f'Остановка: |x_new - x_curr| = {abs(x_new - x_curr):.4f} < epsilon = {epsilon}')
            return x_new, trace

        x_curr = x_new

    print('Достигнуто максимальное число итераций')
    return x_curr, trace

# %% [markdown]
# ## Задание 7 (1 балл)

# %% [markdown]
# Подберите начальное приближение (сделайте несколько запусков из случайной начальной точки) и шаг градиентного спуска таким образом, чтобы процедура выдавала правильное значение наименьшего локального минимума функций (если он есть):
# - [ ] в качестве результата выведите на экран значение начального приближения ($x_0$), `learning_rate`
# - [ ] нарисуйте график функции и изобразите на нём наименьший из найденных локальных минимумов; на оси $x$ подпишите значение этого минимума. \
# (Постарайтесь сделать реализацию графика в виде функции, чтобы оптимизировать процесс. Потом функция понадобится вам в задании 9, но это не обязательное требование).
# - [ ] если такой точки у функции нет, поясните это текстом при помощи Markdown

# %%
def plot_function_with_minimum(f, x_min, title='График функции'):

    x = np.linspace(-1000, 1000, 2001)
    y = f(x)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label='f(x)', color='blue')
    plt.scatter([x_min], [f(x_min)], color='red', label=f'Локальный минимум: x={x_min:.2f}')
    plt.axvline(x_min, color='red', linestyle='--', alpha=0.7)
    plt.title(title)
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.legend()
    plt.grid()
    plt.show()


f = lambda x: x**2 - 30*x + 1

epsilon = 1e-6
delta = 1e-4
num_iterations = 1000

for func_name, func in functions.items():
  print(f'\n{func_name}')
  x = sp.symbols('x')
  f = sp.lambdify(x, func)
  results = []
  np.random.seed(12345)
  for i in range(5):
      x_start = np.random.uniform(-1, 4)
      learning_rate = np.random.uniform(0.01, 0.5)

      x_min, trace = gradient_descent(x_start, learning_rate, epsilon, delta, num_iterations, f)
      f_min = f(x_min)
      results.append((x_start, learning_rate, x_min, f_min))

  best_result = min(results, key=lambda item: item[3])

  x_start, learning_rate, x_min, f_min = best_result
  print(f"Лучший результат:")
  print(f"Начальное приближение x0: {x_start:.4f}")
  print(f"Learning rate: {learning_rate:.4f}")
  print(f"Локальный минимум: x = {x_min:.4f}, f(x) = {f_min:.4f}")

  plot_function_with_minimum(f, x_min, title="График функции с локальными минимумами")
# Out:
# x**2 - 30*x + 1
# Остановка: |f'(x)| = 0.0001 < delta = 0.0001
# Остановка: |f'(x)| = 0.0001 < delta = 0.0001
# Остановка: |f'(x)| = 0.0001 < delta = 0.0001
# Остановка: |f'(x)| = 0.0001 < delta = 0.0001
# Остановка: |f'(x)| = 0.0001 < delta = 0.0001
# Лучший результат:
# Начальное приближение x0: 3.8226
# Learning rate: 0.3301
# Локальный минимум: x = 15.0000, f(x) = -224.0000
# -x**3 + 5*x - 7*x**2 + 17
# Достигнуто максимальное число итераций
# Остановка: |f'(x)| = 0.0001 < delta = 0.0001
# Достигнуто максимальное число итераций
# Достигнуто максимальное число итераций
# Достигнуто максимальное число итераций
# Лучший результат:
# Начальное приближение x0: 3.8226
# Learning rate: 0.3301
# ---------------------------------------------------------------------------
# InvalidOperation                          Traceback (most recent call last)
# <ipython-input-27-dcb8d8a8c184> in <cell line: 24>()
#      42   print(f"Начальное приближение x0: {x_start:.4f}")
# ...

# %% [markdown]
# ## Задание 8 (1.5 балла)

# %% [markdown]
# Реализуйте [метод Ньютона](https://en.wikipedia.org/wiki/Newton%27s_method_in_optimization) (метод второго порядка) для поиска минимума функции.
#
# Про метод ещё можно почитать [здесь](https://math.semestr.ru/optim/minimum.php).

# %%
def newton_method(f_expr, x_start, epsilon=1e-6, max_iterations=1000):
    x = sp.symbols('x')

    df = sp.diff(f_expr, x)
    ddf = sp.diff(df, x)

    x_curr = x_start
    trace = [x_curr]

    for _ in range(max_iterations):
        grad = df.subs(x, x_curr)
        hess = ddf.subs(x, x_curr)

        if abs(grad) < epsilon:
            break

        if hess == 0:
            raise ValueError("Вторая производная равна нулю. Метод Ньютона не применим.")

        x_new = x_curr - grad / hess
        trace.append(x_new)
        if abs(x_new - x_curr) < epsilon:
            break

        x_curr = x_new

    x_min = x_curr
    f_min = f_expr.subs(x, x_min)
    return x_min, f_min, trace

# %% [markdown]
# ## Задание 9 (0.5 балла)

# %% [markdown]
# Примените метод Ньютона для поиска минимума указанных функций (в ответе выведите подходящее значение начальной точки, график с найденным и подписанным значением минимума, как в задании 7).

# %%
def plot_newton_method(f, x_min, trace, title='График функции с траекторией метода Ньютона'):

    x = np.linspace(-10, 50, 201)
    y = f(x)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label='x**2 - 30*x + 1', color='blue')
    plt.scatter([x_min], [f(x_min)], color='red', label=f'Локальный минимум: x={x_min:.4f}')
    plt.plot(trace, [f(xi) for xi in trace], 'go--', label='Траектория метода Ньютона')
    plt.axvline(x_min, color='red', linestyle='--', alpha=0.7)
    plt.title(title)
    plt.xlabel('x')
    plt.ylabel('x**2 - 30*x + 1')
    plt.legend()
    plt.grid()
    plt.show()


x = sp.symbols('x')
f_expr = x**2 - 30*x + 1
f = sp.lambdify(x, f_expr)

x_start = 0.5
epsilon = 1e-6
max_iterations = 1000

for func_name, func in functions.items():
    print(f'\n{func_name}')
    x_min, f_min, trace = newton_method(func, x_start, epsilon, max_iterations)

    x = sp.symbols('x')
    f = sp.lambdify(x, func)

    print(f'Метод Ньютона:'
        f'\nНачальная точка: x_start = {x_start}'
        f'\nНайденный минимум: x_min = {x_min}'
        f'\nЗначение функции в минимуме: f(x_min) = {f_min}')

    plot_newton_method(f, x_min, trace, title='Метод Ньютона - Поиск локального минимума')
# Out:
# x**2 - 30*x + 1
# Метод Ньютона:
# Начальная точка: x_start = 0.5
# Найденный минимум: x_min = 15.0000000000000
# Значение функции в минимуме: f(x_min) = -224.000000000000
# -x**3 + 5*x - 7*x**2 + 17
# Метод Ньютона:
# Начальная точка: x_start = 0.5
# Найденный минимум: x_min = 0.333333333337126
# Значение функции в минимуме: f(x_min) = 17.8518518518519
# x**2 - 1/x
# Метод Ньютона:
# Начальная точка: x_start = 0.5
# Найденный минимум: x_min = -0.793700524258510
# Значение функции в минимуме: f(x_min) = 1.88988157484231
# 1/x**5 + x**17 + 8
# Метод Ньютона:
# Начальная точка: x_start = 0.5
# Найденный минимум: x_min = 0.945892701773534
# Значение функции в минимуме: f(x_min) = 9.70908799027154

# %% [markdown]
# ## Задание 10 (1 балл)

# %% [markdown]
# Сравните скорость работы градиентного спуска и метода Ньютона при одинаковой точности решения $|x_{found}-x_{true}|<10^{-5}$:
# * за сколько итераций каждый метод сходится (в среднем по всем функциям для правильно подобранных значений гиперпараметров)? Какой быстрее?
# * какой метод дает более точный результат при фиксированном числе итераций $N=10$? (для ответа на этот вопрос добавьте в процедуру градиентного спуска возможность останавливаться при достижении некоторого количества итераций $N$)

# %%
def new_gradient_descent(f_expr, x_start, learning_rate=0.1, epsilon=1e-6, max_iterations=1000):
    x = sp.symbols('x')
    df = sp.diff(f_expr, x)

    x_curr = x_start
    trace = [x_curr]

    for i in range(max_iterations):
        grad = df.subs(x, x_curr)

        if abs(grad) < epsilon:
            break

        x_new = x_curr - learning_rate * grad
        trace.append(x_new)

        if abs(x_new - x_curr) < epsilon:
            break

        x_curr = x_new

    print('Достигнуто максимальное число итераций')
    return x_curr, f_expr.subs(x, x_curr), trace, i + 1

def new_newton_method(f_expr, x_start, epsilon=1e-6, max_iterations=1000):
    x = sp.symbols('x')

    df = sp.diff(f_expr, x)
    ddf = sp.diff(df, x)

    x_curr = x_start
    trace = [x_curr]

    for i in range(max_iterations):
        grad = df.subs(x, x_curr)
        hess = ddf.subs(x, x_curr)

        if abs(grad) < epsilon:
            break

        if hess == 0:
            raise ValueError("Вторая производная равна нулю. Метод Ньютона не применим.")

        x_new = x_curr - grad / hess
        trace.append(x_new)
        if abs(x_new - x_curr) < epsilon:
            break

        x_curr = x_new

    x_min = x_curr
    f_min = f_expr.subs(x, x_min)
    return x_min, f_min, trace, i + 1

# %%
def compare_methods(f_expr, x_true, x_start, learning_rate=0.1, epsilon=1e-5, max_iterations=1000):
    def safe_format(value, precision=6):
        try:
            return f'{float(value):.{precision}f}'
        except (TypeError, ValueError):
            return str(value)

    x_newton, f_newton, trace_newton, n_iter_newton = new_newton_method(
        f_expr, x_start, epsilon, max_iterations
    )
    x_grad, f_grad, trace_grad, n_iter_grad = new_gradient_descent(
        f_expr, x_start, learning_rate, epsilon, max_iterations
    )
    _, f_grad_n, trace_grad_n, _ = new_gradient_descent(
        f_expr, x_start, learning_rate, epsilon, max_iterations=10
    )

    print(f'Точное значение минимума x_true = {safe_format(x_true, precision=5)}')
    print('Сравнение:')
    print(
        f'Метод Ньютона:\n'
        f' Пройдено итераций: {n_iter_newton}, Найденное значение: x = {safe_format(x_newton)}, f(x) = {safe_format(f_newton)}\n'
    )
    print(
        f'Градиентный спуск (скорость сходимости):\n'
        f' Пройдено итераций: {n_iter_grad}, Найденное значение: x = {safe_format(x_grad)}, f(x) = {safe_format(f_grad)}\n'
    )
    print(
        f'Градиентный спуск (точность после N=10 итераций):\n'
        f' Найденное значение: x = {safe_format(trace_grad_n[-1])}, f(x) = {safe_format(f_grad_n)}\n'
    )


x = sp.symbols('x')
x_true = 2.0
x_start = 0.1
learning_rate = 0.01
epsilon = 1e-5

for func_name, func in functions.items():
    print(f'\n{func_name}')
    compare_methods(func, x_true, x_start, learning_rate, epsilon)
# Out:
# x**2 - 30*x + 1
# Достигнуто максимальное число итераций
# Достигнуто максимальное число итераций
# Точное значение минимума x_true = 2.00000
# Сравнение:
# Метод Ньютона:
#  Пройдено итераций: 2, Найденное значение: x = 15.000000, f(x) = -224.000000
#
# Градиентный спуск (скорость сходимости):
#  Пройдено итераций: 511, Найденное значение: x = 14.999501, f(x) = -224.000000
#
# Градиентный спуск (точность после N=10 итераций):
#  Найденное значение: x = 2.825615, f(x) = -75.784354
#
#
# -x**3 + 5*x - 7*x**2 + 17
# Достигнуто максимальное число итераций
# Достигнуто максимальное число итераций
# Точное значение минимума x_true = 2.00000
# Сравнение:
# Метод Ньютона:
#  Пройдено итераций: 4, Найденное значение: x = 0.333333, f(x) = 17.851852
#
# Градиентный спуск (скорость сходимости):
#  Пройдено итераций: 88, Найденное значение: x = -4.999947, f(x) = -58.000000
#
# Градиентный спуск (точность после N=10 итераций):
#  Найденное значение: x = -0.577169, f(x) = 11.974553
#
#
# ...

# %% [markdown]
# ## **Бонусная часть**

# %% [markdown]
# ## Задание 11 (1 балл)

# %% [markdown]
# Реализуйте оптимизацию метода градиентного спуска - Momentum. Необходимые выкладки вы можете подсмотреть [здесь](https://education.yandex.ru/handbook/ml/article/optimizaciya-v-ml).

# %%
# your code here

# %% [markdown]
# ## Задание 12 (0.5 балла)

# %% [markdown]
# Проверьте, решает ли Momentum GD проблему поиска начального приближения для функций из задания 1?

# %%
# your code here

# %% [markdown]
# ## **Часть Котобонус** 🐈
#
# Ура-ура, с вами снова кот, который может добавить вам баллы!
# - 0.25, если вы угадаете, чей он
# - 0.05 если просто предположите
#
# **Подсказка:** кот одной из наших замечательных ассистенток!
#
#
# [Кайфующий кот](https://ibb.co/12WN7wg)
